# %%
import pandas as pd
import numpy as np
import googlemaps
from datetime import datetime

# %%
maps_key = "AIzaSyAAwZ4zfo0Q2L7m7qP335-fmUyASvuprqA"
gmaps = googlemaps.Client(key=maps_key)

# %%
travel_data = pd.read_csv("MOCK_DATA.csv")

# %%
travel_data
# Out:
#        id        Country                 State   Location Name  Latitude  \
# 0       1  United States                 Texas        Amarillo   35.4015
# 1       2  United States            California      Sacramento   38.4826
# 2       3  United States          Pennsylvania      Pittsburgh   40.4344
# 3       4  United States  District of Columbia      Washington   38.8933
# 4       5  United States               Florida       Pensacola   30.6143
# 5       6  United States               Florida       Homestead   25.2846
# 6       7  United States              Michigan         Detroit   42.2399
# 7       8  United States               Florida         Orlando   28.5289
# 8       9  United States               Arizona          Tucson   32.3366
# 9      10  United States              Colorado          Denver   39.7388
# 10     11  United States              Missouri     Springfield   37.1803
# 11     12  United States              Michigan         Detroit   42.2719
# 12     13  United States           Connecticut       Fairfield   41.1928
# 13     14  United States            California     Los Angeles   34.0434
# 14     15  United States            California       Oceanside   33.1968
# 15     16  United States             Louisiana     Baton Rouge   30.4860
# 16     17  United States              Oklahoma   Oklahoma City   35.4210
# 17     18  United States  District of Columbia      Washington   38.8933
# 18     19  United States                 Texas         El Paso   31.7444
# 19     20  United States                Nevada     Carson City   39.2025
# 20     21  United States            California     Los Angeles   33.9754
# 21     22  United States            California        Berkeley   37.6802
# 22     23  United States               Indiana      Evansville   37.9971
# 23     24  United States            California   San Francisco   37.7848
# 24     25  United States              Maryland       Baltimore   39.2856
# 25     26  United States               Florida         Hialeah   25.9098
# 26     27  United States              Colorado          Denver   39.7783
# 27     28  United States             Tennessee       Nashville   36.1114
# 28     29  United States            California        Pasadena   33.7866
# 29     30  United States               Florida       Kissimmee   27.9953
# ..    ...            ...                   ...             ...       ...
# 970   971  United States  District of Columbia      Washington   38.8933
# 971   972  United States         Massachusetts       Cambridge   42.3620
# 972   973  United States              Virginia       Lynchburg   37.4009
# 973   974  United States                Nevada            Reno   39.7699
# 974   975  United States             Minnesota      Saint Paul   44.8060
# 975   976  United States          Pennsylvania      Pittsburgh   40.5051
# 976   977  United States                  Ohio      Cincinnati   39.1110
# 977   978  United States              Michigan    Grand Rapids   43.0314
# 978   979  United States                  Utah  Salt Lake City   40.7286
# 979   980  United States               Indiana      Evansville   37.9971
# 980   981  United States         Massachusetts       Worcester   42.2894
# 981   982  United States               Georgia         Augusta   33.4130
# 982   983  United States             Wisconsin         Madison   43.0696
# 983   984  United States               Indiana      Fort Wayne   41.0938
# 984   985  United States              New York   New York City   40.7808
# 985   986  United States                  Ohio      Cincinnati   39.2692
# 986   987  United States         Massachusetts        Brockton   41.9705
# 987   988  United States              Virginia        Richmond   37.5242
# 988   989  United States               Florida      Clearwater   27.8918
# 989   990  United States               Florida         Hialeah   25.8594
# 990   991  United States        South Carolina        Columbia   34.0635
# 991   992  United States            Washington         Seattle   47.6849
# 992   993  United States               Florida           Miami   25.5584
# 993   994  United States               Florida    Winter Haven   27.9810
# 994   995  United States             Tennessee       Nashville   36.1114
# 995   996  United States          Pennsylvania      Harrisburg   40.2618
# 996   997  United States                 Texas     San Antonio   29.3977
# 997   998  United States         Massachusetts        Brockton   41.9705
# 998   999  United States              Oklahoma   Oklahoma City   35.3425
# 999  1000  United States               Indiana            Gary   41.5878
#
#      Longitude  Number of Parcels
# 0    -101.8951                 37
# 1    -121.4006                 53
# 2     -80.0248                 93
# 3     -77.0146                 69
# 4     -87.2758                 85
# 5     -80.6246                  3
# 6     -83.1508                100
# 7     -81.4787                 95
# 8    -111.1771                 49
# 9    -104.4083                 40
# 10    -93.2951                 37
# 11    -83.1545                 43
# 12    -73.2402                 95
# 13   -118.2716                 16
# 14   -117.2831                 31
# 15    -91.1481                 37
# 16    -97.5616                 73
# 17    -77.0146                  7
# 18   -106.2879                 37
# 19   -119.7526                 71
# 20   -118.4170                 62
# 21   -121.9215                 33
# 22    -87.5750                 92
# 23   -122.7278                 21
# 24    -76.6899                100
# 25    -80.3889                 63
# 26   -104.7556                 81
# 27    -86.8690                 79
# 28   -118.2987                 99
# 29    -81.2593                 35
# ..         ...                ...
# 970   -77.0146                 11
# 971   -71.0830                 41
# 972   -79.1785                 66
# 973  -119.6027                 33
# 974   -93.1409                 85
# 975   -80.1155                 35
# 976   -84.6594                 96
# 977   -85.5503                  8
# 978  -111.6627                 69
# 979   -87.5750                 59
# 980   -71.7888                 79
# 981   -82.1337                 74
# 982   -89.4239                  7
# 983   -85.0707                 30
# 984   -73.9772                 25
# 985   -84.3307                 82
# 986   -70.7014                 76
# 987   -77.4932                  6
# 988   -82.7248                  4
# 989   -80.2725                 12
# 990   -81.0265                 96
# 991  -122.2968                  9
# 992   -80.4582                 96
# 993   -81.6736                 27
# 994   -86.8690                  4
# 995   -76.8800                 92
# 996   -98.4658                 52
# 997   -70.7014                 86
# 998   -97.6317                 66
# 999   -87.4062                 48
#
# [1000 rows x 7 columns]

# %%
final_list = pd.DataFrame(index=np.linspace(1,20,20),columns=['Destination','Dist','Time'])

# %%
dist = dict()

# %%
travel_data_sorted = travel_data.groupby(['Location Name','Latitude','Longitude']).sum()
#travel_data_sorted

# %%
Unique_Locations = list(set(travel_data['Location Name']))

# %%
steps = 20
Unique_Locations_DF= pd.DataFrame(index=np.linspace(1,steps,steps),columns=['Destination'])

# %%
shortened = dict()
for i in range(1,steps):
    shortened[i] = gmaps.geocode(Unique_Locations[i])
# Out:
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# <ipython-input-10-00153bfb6cbf> in <module>()
#       1 shortened = dict()
#       2 for i in range(1,steps):
# ----> 3     shortened[i] = gmaps.geocode(Unique_Locations[i])
#
# /Users/sabyasachi/anaconda/lib/python2.7/site-packages/googlemaps/client.pyc in wrapper(*args, **kwargs)
#     354     def wrapper(*args, **kwargs):
#     355         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 356         result = func(*args, **kwargs)
#     357         try:
#     358             del args[0]._extra_params
#
# /Users/sabyasachi/anaconda/lib/python2.7/site-packages/googlemaps/geocoding.pyc in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params)["results"]
#      69
#      70
#
# /Users/sabyasachi/anaconda/lib/python2.7/site-packages/googlemaps/client.pyc in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     231             raise googlemaps.exceptions.Timeout()
#     232         except Exception as e:
# --> 233             raise googlemaps.exceptions.TransportError(e)
#     234
#     235         if response.status_code in _RETRIABLE_STATUSES:
#
# TransportError: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Albany&key=AIzaSyAAwZ4zfo0Q2L7m7qP335-fmUyASvuprqA (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x10cc0cb50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
for i in range(1,steps-1):#len(Unique_Locations)):
    Unique_Locations_DF['Destination'][i] = shortened[i][0]['formatted_address']

# %%
warehouse = Unique_Locations_DF['Destination'][1]
travel_route = pd.Series(index=np.linspace(1,20,20)).astype(str)
travel_route[1] = warehouse

# %%
#For Limitation Using Steps
def Distance_Table(origin,destinations,steps):
    for j in range(1,10):#steps):
        dist[j] = gmaps.distance_matrix(origin,destinations[j])
    return dist

# %%
#Defining The Distance and Time Table
def Table_Define(dist):
    for i in range(1,len(dist)):
        final_list['Destination'][i] = dist[i]['destination_addresses'][0]
        final_list['Dist'][i] = dist[i]['rows'][0]['elements'][0]['distance']['value']
        final_list['Time'][i] = dist[i]['rows'][0]['elements'][0]['duration']['value']
    return final_list

# %%
# Computing For 10 Locations
j = 1
for i in range(1,10):
    Distance_Table(travel_route[i],Unique_Locations_DF['Destination'],steps)
    Table_Define(dist)
    sorted_list = final_list.sort_values(by='Time')
    travel_route[j]=sorted_list.iloc[0]['Destination']
    print sorted_list.iloc[0]['Destination']
    a = Unique_Locations_DF[Unique_Locations_DF['Destination']==travel_route[j]].index[0]
    j=j+1
    Unique_Locations_DF.drop(Unique_Locations_DF.index[a],inplace= True)
    Unique_Locations_DF = Unique_Locations_DF.reset_index(drop=True)

# %%
travel_route
# Out:
# 1.0            Albany, NY, USA
# 2.0        Montgomery, AL, USA
# 3.0     Winston-Salem, NC, USA
# 4.0            Toledo, OH, USA
# 5.0       Spartanburg, SC, USA
# 6.0         Frederick, MD, USA
# 7.0             Tyler, TX, USA
# 8.0         Lynchburg, VA, USA
# 9.0              Kent, OH, USA
# 10.0                       nan
# 11.0                       nan
# 12.0                       nan
# 13.0                       nan
# 14.0                       nan
# 15.0                       nan
# 16.0                       nan
# 17.0                       nan
# 18.0                       nan
# 19.0                       nan
# 20.0                       nan
# dtype: object
