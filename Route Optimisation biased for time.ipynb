# %%
import pandas as pd
import numpy as np
import googlemaps
from datetime import datetime

# %%
maps_key = "AIzaSyAAwZ4zfo0Q2L7m7qP335-fmUyASvuprqA"
gmaps = googlemaps.Client(key=maps_key)

# %% [markdown]
# Travel_Data is Randomly Created Unique Locations in United States.

# %%
travel_data = pd.read_csv("MOCK_DATA.csv")

# %%
travel_data.head(5)
# Out:
#    id        Country                 State Location Name  Latitude  Longitude  \
# 0   1  United States                 Texas      Amarillo   35.4015  -101.8951
# 1   2  United States            California    Sacramento   38.4826  -121.4006
# 2   3  United States          Pennsylvania    Pittsburgh   40.4344   -80.0248
# 3   4  United States  District of Columbia    Washington   38.8933   -77.0146
# 4   5  United States               Florida     Pensacola   30.6143   -87.2758
#
#    Number of Parcels
# 0                 37
# 1                 53
# 2                 93
# 3                 69
# 4                 85

# %% [markdown]
# Creating final_list Data Frame which iteratively stores the Distance and Time taken from the last location where the item was delivered or from the warehouse.

# %%
final_list = pd.DataFrame(index=np.linspace(1,20,20),columns=['Destination','Dist','Time'])
final_list.head(5)
# Out:
#     Destination Dist Time
# 1.0         NaN  NaN  NaN
# 2.0         NaN  NaN  NaN
# 3.0         NaN  NaN  NaN
# 4.0         NaN  NaN  NaN
# 5.0         NaN  NaN  NaN

# %%
dist = dict()

# %%
travel_data_sorted = travel_data.groupby(['Location Name','Latitude','Longitude']).sum()

# %% [markdown]
# Grouping the total Parcels to be delivered and Different locations to be visited in a particular city.

# %%
travel_data_sorted
# Out:
#                                        id  Number of Parcels
# Location Name   Latitude Longitude
# Akron           41.0280  -81.4632     866                 48
#                 41.1075  -81.5006    1698                 79
# Albany          42.6149  -73.9708    2262                257
#                 42.6568  -73.7605     355                 64
#                 42.7198  -73.8207    2065                121
# Albuquerque     35.0443  -106.6729   4985                513
#                 35.0448  -106.6893    820                 32
#                 35.0512  -106.7269    634                 56
#                 35.1104  -106.5781    593                175
# Alexandria      38.8158  -77.0900     274                  7
#                 38.8200  -77.0589     377                  3
# Amarillo        35.1885  -101.8165    776                 41
#                 35.4015  -101.8951   3310                195
# Anaheim         33.8356  -117.9132   1274                 94
# ...

# %%
#Finding the Unique List of Cities to be visited
Unique_Locations = list(set(travel_data['Location Name']))

# %%
steps = 20
Unique_Locations_DF= pd.DataFrame(index=np.linspace(1,steps,steps),columns=['Destination'])

# %% [markdown]
# GeoCoding all the Locations to prevent mismatch from Google Maps Place names into a Dictionary shortened.

# %%
shortened = dict()
for i in range(1,steps):
    shortened[i] = gmaps.geocode(Unique_Locations[i])

# %%
for i in range(1,steps-1):
    Unique_Locations_DF['Destination'][i] = shortened[i][0]['formatted_address']

# %% [markdown]
# Storing the Unique Geocoded Locations into a Data Frame and Using the First Location as the Warehouse/Origin.

# %%
warehouse = Unique_Locations_DF['Destination'][1]
travel_route = pd.Series(index=np.linspace(1,20,20)).astype(str)
travel_route[1] = warehouse

# %%
#For Limitation Using Steps
def Distance_Table(origin,destinations,steps):
    for j in range(1,10):#steps):
        dist[j] = gmaps.distance_matrix(origin,destinations[j])
    return dist

# %%
#Defining The Distance and Time Table
def Table_Define(dist):
    for i in range(1,len(dist)):
        final_list['Destination'][i] = dist[i]['destination_addresses'][0]
        final_list['Dist'][i] = dist[i]['rows'][0]['elements'][0]['distance']['value']
        final_list['Time'][i] = dist[i]['rows'][0]['elements'][0]['duration']['value']
    return final_list

# %%
# Computing For 10 Locations
j = 1
for i in range(1,10):
    Distance_Table(travel_route[i],Unique_Locations_DF['Destination'],steps)
    Table_Define(dist)
    sorted_list = final_list.sort_values(by='Time')
    travel_route[j]=sorted_list.iloc[0]['Destination']
    print sorted_list.iloc[0]['Destination']
    a = Unique_Locations_DF[Unique_Locations_DF['Destination']==travel_route[j]].index[0]
    j=j+1
    Unique_Locations_DF.drop(Unique_Locations_DF.index[a],inplace= True)
    Unique_Locations_DF = Unique_Locations_DF.reset_index(drop=True)

# %%
travel_route
# Out:
# 1.0            Albany, NY, USA
# 2.0        Montgomery, AL, USA
# 3.0     Winston-Salem, NC, USA
# 4.0            Toledo, OH, USA
# 5.0       Spartanburg, SC, USA
# 6.0         Frederick, MD, USA
# 7.0             Tyler, TX, USA
# 8.0         Lynchburg, VA, USA
# 9.0              Kent, OH, USA
# 10.0                       nan
# 11.0                       nan
# 12.0                       nan
# 13.0                       nan
# 14.0                       nan
# 15.0                       nan
# 16.0                       nan
# 17.0                       nan
# 18.0                       nan
# 19.0                       nan
# 20.0                       nan
# dtype: object
